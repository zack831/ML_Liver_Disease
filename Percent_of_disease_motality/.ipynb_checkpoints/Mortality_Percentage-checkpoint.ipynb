# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/zack83/Dropbox/Tripura_University/Project_Final/Databases/Final_Databases/FULL_Non-Liver_Merged.csv")

# %%
df
# Out:
#        AGE  GENDER  ALBUMIN  BILIRUBIN  ALK_PHOSPHATE    SGOT  ASCITES  \
# 0     56.0       1     4.14        1.1         7394.8  113.52      0.0
# 1     38.0       1     3.53        3.4          671.0  113.15      0.0
# 2     55.0       1     4.09        1.0          824.0   60.45      0.0
# 3     45.0       1     3.85        0.7         1181.0   88.35      0.0
# 4     40.0       1     3.66        0.7          685.0   72.85      0.0
# ...    ...     ...      ...        ...            ...     ...      ...
# 1025  32.0       0     4.60        0.8          178.0   26.00      0.0
# 1026  45.0       0     4.90        0.2          146.0   70.00      0.0
# 1027  31.0       0     2.90        0.2          182.0   28.00      0.0
# 1028  38.0       0     2.90        0.3          215.0   15.00      0.0
# 1029  68.0       1     4.40        0.2          165.0   29.00      0.0
#
#       SPIDERS  PROTHROMBIN  HEPATOMEGALY  PALTELETS  STATUS  CLASS  \
# ...

# %%
died_cr = len(df.loc[(df['CLASS'] == 1) & (df['STATUS'] == 1)])
died_hp = len(df.loc[(df['CLASS'] == 2) & (df['STATUS'] == 1)])
died_hc = len(df.loc[(df['CLASS'] == 3) & (df['STATUS'] == 1)])
total = len(df)

percent = []
data = [died_cr, died_hp, died_hc]

for i in data:
    percent.append(((i/total)*100))

print('For Cirrhosis Mortality percentage:',percent[0])
print('For Hepatitis Mortality percentage::',percent[1])
print('For Hcc Mortality percentage::',percent[2])
# Out:
# For Cirrhosis Mortality percentage: 15.63106796116505
# For Hepatitis Mortality percentage:: 3.1067961165048543
# For Hcc Mortality percentage:: 9.902912621359224
