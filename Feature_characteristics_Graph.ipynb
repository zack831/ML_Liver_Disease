# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/zack83/Dropbox/Tripura_University/Project_Final/Databases/Final_Databases/FULL_Non-Liver_Merged.csv')
df1 = pd.read_csv('/home/zack83/Dropbox/Tripura_University/Project_Final/Databases/Final_Databases/FULL_MERGED_CLEAN.csv')

# %%
# tips = sns.load_dataset("/home/zack83/Dropbox/Tripura_University/Project_Final/Databases/Final_Databases/FULL_Non-Liver_Merged.csv")
plt.figure(figsize = (50,70))
loop = df[["AGE","GENDER","ALBUMIN","BILIRUBIN","ALK_PHOSPHATE","SGOT","ASCITES","SPIDERS","PROTHROMBIN","HEPATOMEGALY","PALTELETS","ALPHA-FETOPROTEIN","FERRITIN","HEMOGLOBIN","PROTINE","VARICES","MALAISE","STATUS"]]
i = 0
for c in loop:
    i +=1
    plt.subplot(9,2,i)
    # sns.kdeplot(df, x=df[c], hue=df["CLASS"], fill=True)
    # plt.title("Distribution of Petal Lengths, by Species")
    # sns.regplot(x = df[c],y = df["CLASS"],scatter=False, color='orchid',)
    # sns.swarmplot( x=df[c], y=df["CLASS"])
    sns.kdeplot( x=df[c], hue=df["CLASS"],fill =True)
    # sns.lmplot(data = df,x=df[c], y=df["CLASS"], hue=df["CLASS"])
    # sns.scatterplot(data= df, x=df[c], y=df["CLASS"], hue="CLASS", style="CLASS")
# Out:
# /tmp/ipykernel_12600/3283859900.py:12: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot( x=df[c], hue=df["CLASS"],fill =True)
# /tmp/ipykernel_12600/3283859900.py:12: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot( x=df[c], hue=df["CLASS"],fill =True)
# /tmp/ipykernel_12600/3283859900.py:12: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot( x=df[c], hue=df["CLASS"],fill =True)
# /tmp/ipykernel_12600/3283859900.py:12: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot( x=df[c], hue=df["CLASS"],fill =True)
# ...

# %%
# sns.kdeplot(df, x="PROTINE", hue="CLASS", fill=True)
# sns.scatterplot(data= df, x="PROTINE", y="CLASS", hue="CLASS", style="CLASS")

# %%
# sns.lmplot(data = df, x="AGE", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="GENDER", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="ALBUMIN", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="BILIRUBIN", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="ALK_PHOSPHATE", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="ASCITES", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="SPIDERS", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="PROTHROMBIN", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="HEPATOMEGALY", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="PALTELETS", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="ALPHA-FETOPROTEIN", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="FERRITIN", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="HEMOGLOBIN", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="PROTINE", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="VARICES", y="CLASS", hue="CLASS")
# sns.lmplot(data = df, x="MALAISE", y="CLASS", hue="CLASS")

# %%
# tips = sns.load_dataset("/home/zack83/Dropbox/Tripura_University/Project_Final/Databases/Final_Databases/FULL_Non-Liver_Merged.csv")
plt.figure(figsize = (50,70))
loop = df1[["AGE","GENDER","ALBUMIN","BILIRUBIN","ALK_PHOSPHATE","SGOT","ASCITES","SPIDERS","PROTHROMBIN","HEPATOMEGALY","PALTELETS","ALPHA-FETOPROTEIN","FERRITIN","HEMOGLOBIN","PROTINE","VARICES","MALAISE","CLASS"]]
i = 0
for c in loop:
    i +=1
    plt.subplot(9,2,i)
    # sns.kdeplot(df, x=df[c], hue=df["CLASS"], fill=True)
    # plt.title("Distribution of Petal Lengths, by Species")
    # sns.regplot(x = df[c],y = df["CLASS"],scatter=False, color='orchid',)
    # sns.swarmplot( x=df[c], y=df["CLASS"])
    sns.kdeplot( x=df[c], hue=df["STATUS"],fill = True)
    # sns.lmplot(data = df,x=df[c], y=df["CLASS"], hue=df["CLASS"])
    # sns.scatterplot(data= df, x=df[c], y=df["CLASS"], hue="CLASS", style="CLASS")
